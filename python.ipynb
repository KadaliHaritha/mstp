# %%
from mpl_toolkits.mplot3d import axes3d

# %%
from matplotlib import style

# %%
style.use('fivethirtyeight')

# %%
import matplotlib.pyplot as pt

# %%
fig=pt.figure()
a=fig.add_subplot(111,projection='3d')
x=[1,2,3,4]
y=[2,4,5,6]
z=[1,4,5,6]
a.plot(x,y,z)
a.set_xlabel('x-axis')
a.set_ylabel('y-axis')
a.set_zlabel('z-axis')
# Out:
# Text(0.5, 0, 'z-axis')

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

# %% [markdown]
# ## time series

# %%
from datetime import datetime

# %%
a=datetime.now()

# %%
a
# Out:
# datetime.datetime(2020, 1, 3, 14, 13, 5, 722100)

# %%
a.date()
# Out:
# datetime.date(2020, 1, 3)

# %%
a.year
# Out:
# 2020

# %%
a.day
# Out:
# 3

# %%
from datetime import*

# %%
now=datetime.now()

# %%
print("date : {}-{}-{}".format(now.day,now.month,now.year))
# Out:
# date : 3-1-2020

# %%
print("time : {}:{}:{}:{}".format(now.hour,now.minute,now.second,now.microsecond))
# Out:
# time : 14:13:6:29607

# %%
df=a.today()
df
# Out:
# datetime.datetime(2020, 1, 3, 14, 13, 6, 157067)

# %%
df=datetime.today()
print(df)
t=date.today()
print(t)
# Out:
# 2020-01-03 14:13:06.192605
# 2020-01-03

# %%
t=datetime(2020,1,2)-datetime(1999,10,3,9,46,0)

# %%
t
# Out:
# datetime.timedelta(days=7395, seconds=51240)

# %%
t=datetime(2020,1,2)-datetime(1999,10,3,9,46,0)
t.days
# Out:
# 7395

# %%
t=datetime(2020,1,2)-datetime(1999,10,3,9,46,0)
print(t.seconds)
print(t.days)
print(t.total_seconds())
t
# Out:
# 51240
# 7395
# 638979240.0
# datetime.timedelta(days=7395, seconds=51240)

# %%
datetime(2020,1,3)
# Out:
# datetime.datetime(2020, 1, 3, 0, 0)

# %%
datetime(2020,1,3)+timedelta(200)
# Out:
# datetime.datetime(2020, 7, 21, 0, 0)

# %%
datetime(2020,1,3)-timedelta(100)
# Out:
# datetime.datetime(2019, 9, 25, 0, 0)

# %%
t="3 january 2020"
datetime.strptime(t,"%d %B %Y")
# Out:
# datetime.datetime(2020, 1, 3, 0, 0)

# %%
a=datetime.today()
a.strftime("%d,%b,%Y")
# Out:
# '03,Jan,2020'

# %%
a=[datetime(2020,2,3),datetime(2019,1,4),datetime(2018,2,10)]

# %%
a
# Out:
# [datetime.datetime(2020, 2, 3, 0, 0),
#  datetime.datetime(2019, 1, 4, 0, 0),
#  datetime.datetime(2018, 2, 10, 0, 0)]

# %%
b=[i.strftime("%d,%b,%Y") for i in a]
b
# Out:
# ['03,Feb,2020', '04,Jan,2019', '10,Feb,2018']

# %%
b=[i.strftime("%d,%B,%Y") for i in a]
b
# Out:
# ['03,February,2020', '04,January,2019', '10,February,2018']

# %%
b=[i.strftime("%d,%b,%y") for i in a]

# %%
b
# Out:
# ['03,Feb,20', '04,Jan,19', '10,Feb,18']

# %%
import pandas as pd
import numpy as np

# %%
dates=[datetime(2020,2,3),datetime(2019,1,4),datetime(2018,2,10),datetime(2017,4,20),datetime(2016,4,12)]

# %%
a=pd.Series(np.random.rand(5),index=dates)
a
# Out:
# 2020-02-03    0.179493
# 2019-01-04    0.855531
# 2018-02-10    0.561911
# 2017-04-20    0.867575
# 2016-04-12    0.120401
# dtype: float64

# %%
a.index
# Out:
# DatetimeIndex(['2020-02-03', '2019-01-04', '2018-02-10', '2017-04-20',
#                '2016-04-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
a.values
# Out:
# array([0.17949258, 0.85553064, 0.56191078, 0.86757467, 0.12040073])

# %%
a["2016-04"]
# Out:
# 2016-04-12    0.120401
# dtype: float64

# %%
a["2016"]
# Out:
# 2016-04-12    0.120401
# dtype: float64

# %%
a.index[3]
# Out:
# Timestamp('2017-04-20 00:00:00')

# %%
n=datetime.now()
timestamp=n.timestamp()
timestamp
# Out:
# 1578040987.751223

# %%
a=pd.Series(np.random.rand(1000),index=pd.date_range(start="18/2/1999",periods=1000))
a
# Out:
# 1999-02-18    0.676283
# 1999-02-19    0.787377
# 1999-02-20    0.952527
# 1999-02-21    0.697497
# 1999-02-22    0.730970
# 1999-02-23    0.738721
# 1999-02-24    0.242554
# 1999-02-25    0.072299
# 1999-02-26    0.508924
# 1999-02-27    0.450609
# 1999-02-28    0.612416
# 1999-03-01    0.273821
# 1999-03-02    0.558592
# 1999-03-03    0.340736
# 1999-03-04    0.802612
# 1999-03-05    0.155789
# 1999-03-06    0.634537
# 1999-03-07    0.189961
# 1999-03-08    0.831495
# 1999-03-09    0.090752
# 1999-03-10    0.285266
# 1999-03-11    0.936835
# 1999-03-12    0.370674
# 1999-03-13    0.606938
# 1999-03-14    0.951945
# 1999-03-15    0.354327
# 1999-03-16    0.558590
# 1999-03-17    0.754354
# 1999-03-18    0.792134
# 1999-03-19    0.388078
#                 ...
# 2001-10-15    0.205253
# 2001-10-16    0.557088
# 2001-10-17    0.472440
# 2001-10-18    0.499561
# 2001-10-19    0.120135
# 2001-10-20    0.898694
# 2001-10-21    0.375670
# 2001-10-22    0.137624
# 2001-10-23    0.325522
# ...

# %%
a["2000"]
# Out:
# 2000-01-01    0.020798
# 2000-01-02    0.080341
# 2000-01-03    0.577965
# 2000-01-04    0.345875
# 2000-01-05    0.939930
# 2000-01-06    0.786814
# 2000-01-07    0.434243
# 2000-01-08    0.012794
# 2000-01-09    0.785943
# 2000-01-10    0.381754
# 2000-01-11    0.484636
# 2000-01-12    0.194764
# 2000-01-13    0.712330
# 2000-01-14    0.738723
# 2000-01-15    0.285604
# 2000-01-16    0.102299
# 2000-01-17    0.343418
# 2000-01-18    0.371792
# 2000-01-19    0.314074
# 2000-01-20    0.969311
# 2000-01-21    0.017277
# 2000-01-22    0.195977
# 2000-01-23    0.450245
# 2000-01-24    0.599886
# 2000-01-25    0.224803
# 2000-01-26    0.351788
# 2000-01-27    0.480334
# 2000-01-28    0.443895
# 2000-01-29    0.197665
# 2000-01-30    0.715295
#                 ...
# 2000-12-02    0.628464
# 2000-12-03    0.144562
# 2000-12-04    0.913020
# 2000-12-05    0.089481
# 2000-12-06    0.280181
# 2000-12-07    0.904358
# 2000-12-08    0.949587
# 2000-12-09    0.338640
# 2000-12-10    0.584072
# ...

# %%
a["2000-01-05" : "2000-01-30"]
# Out:
# 2000-01-05    0.939930
# 2000-01-06    0.786814
# 2000-01-07    0.434243
# 2000-01-08    0.012794
# 2000-01-09    0.785943
# 2000-01-10    0.381754
# 2000-01-11    0.484636
# 2000-01-12    0.194764
# 2000-01-13    0.712330
# 2000-01-14    0.738723
# 2000-01-15    0.285604
# 2000-01-16    0.102299
# 2000-01-17    0.343418
# 2000-01-18    0.371792
# 2000-01-19    0.314074
# 2000-01-20    0.969311
# 2000-01-21    0.017277
# 2000-01-22    0.195977
# 2000-01-23    0.450245
# 2000-01-24    0.599886
# 2000-01-25    0.224803
# 2000-01-26    0.351788
# 2000-01-27    0.480334
# 2000-01-28    0.443895
# 2000-01-29    0.197665
# 2000-01-30    0.715295
# Freq: D, dtype: float64

# %%
pd.date_range("2020/01/02","02/01/2021",freq="BM")
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-28', '2020-03-31', '2020-04-30',
#                '2020-05-29', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-30', '2020-11-30', '2020-12-31',
#                '2021-01-29'],
#               dtype='datetime64[ns]', freq='BM')

# %%
pd.date_range("2020/01/02","02/01/2021",freq="WOM-3FRI")
# Out:
# DatetimeIndex(['2020-01-17', '2020-02-21', '2020-03-20', '2020-04-17',
#                '2020-05-15', '2020-06-19', '2020-07-17', '2020-08-21',
#                '2020-09-18', '2020-10-16', '2020-11-20', '2020-12-18',
#                '2021-01-15'],
#               dtype='datetime64[ns]', freq='WOM-3FRI')

# %%
pd.date_range("2020/01/02","02/01/2021",freq="SM")
# Out:
# DatetimeIndex(['2020-01-15', '2020-01-31', '2020-02-15', '2020-02-29',
#                '2020-03-15', '2020-03-31', '2020-04-15', '2020-04-30',
#                '2020-05-15', '2020-05-31', '2020-06-15', '2020-06-30',
#                '2020-07-15', '2020-07-31', '2020-08-15', '2020-08-31',
#                '2020-09-15', '2020-09-30', '2020-10-15', '2020-10-31',
#                '2020-11-15', '2020-11-30', '2020-12-15', '2020-12-31',
#                '2021-01-15', '2021-01-31'],
#               dtype='datetime64[ns]', freq='SM-15')

# %%
pd.date_range("2020/01/02","02/01/2021",freq="A")
# Out:
# DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range("2020/01/02","02/01/2021",freq="BQ")
# Out:
# DatetimeIndex(['2020-03-31', '2020-06-30', '2020-09-30', '2020-12-31'], dtype='datetime64[ns]', freq='BQ-DEC')

# %%
dates=pd.date_range(start="2019/1/2",periods=100)

# %%
a=pd.DataFrame(np.random.rand(100,4),index=dates,columns=["chennai","hyderabad","banglore","delhi"])

# %%
a
# Out:
#              chennai  hyderabad  banglore     delhi
# 2019-01-02  0.468631   0.062762  0.689010  0.944592
# 2019-01-03  0.851682   0.768916  0.018797  0.502806
# 2019-01-04  0.473615   0.349498  0.926514  0.550030
# 2019-01-05  0.754669   0.926630  0.678578  0.953003
# 2019-01-06  0.273504   0.115278  0.818043  0.109099
# 2019-01-07  0.939871   0.478609  0.233282  0.859676
# 2019-01-08  0.300529   0.083427  0.578055  0.539532
# 2019-01-09  0.075539   0.324664  0.566715  0.979672
# 2019-01-10  0.771520   0.128371  0.715771  0.801009
# 2019-01-11  0.104222   0.866722  0.154804  0.393961
# 2019-01-12  0.000356   0.931180  0.212023  0.760485
# 2019-01-13  0.192820   0.629069  0.337680  0.859940
# 2019-01-14  0.869013   0.138310  0.692786  0.501306
# 2019-01-15  0.194098   0.025108  0.819780  0.346780
# 2019-01-16  0.286790   0.285836  0.836110  0.965151
# 2019-01-17  0.835629   0.473382  0.828807  0.492978
# 2019-01-18  0.541079   0.375025  0.553995  0.785354
# ...

# %%
a["chennai"]
# Out:
# 2019-01-02    0.468631
# 2019-01-03    0.851682
# 2019-01-04    0.473615
# 2019-01-05    0.754669
# 2019-01-06    0.273504
# 2019-01-07    0.939871
# 2019-01-08    0.300529
# 2019-01-09    0.075539
# 2019-01-10    0.771520
# 2019-01-11    0.104222
# 2019-01-12    0.000356
# 2019-01-13    0.192820
# 2019-01-14    0.869013
# 2019-01-15    0.194098
# 2019-01-16    0.286790
# 2019-01-17    0.835629
# 2019-01-18    0.541079
# 2019-01-19    0.141317
# 2019-01-20    0.574094
# 2019-01-21    0.786891
# 2019-01-22    0.903599
# 2019-01-23    0.855877
# 2019-01-24    0.588521
# 2019-01-25    0.294157
# 2019-01-26    0.829966
# 2019-01-27    0.464772
# 2019-01-28    0.594329
# 2019-01-29    0.156702
# 2019-01-30    0.238723
# 2019-01-31    0.178530
#                 ...
# 2019-03-13    0.946509
# 2019-03-14    0.520464
# 2019-03-15    0.168828
# 2019-03-16    0.552272
# 2019-03-17    0.624641
# 2019-03-18    0.613106
# 2019-03-19    0.552113
# 2019-03-20    0.145565
# 2019-03-21    0.657722
# ...

# %%
a.index.is_unique
# Out:
# True

# %%
a.loc["2019-03-22":]
# Out:
#              chennai  hyderabad  banglore     delhi
# 2019-03-22  0.858975   0.020235  0.681638  0.098132
# 2019-03-23  0.603357   0.757864  0.606858  0.705534
# 2019-03-24  0.148289   0.724133  0.096228  0.420539
# 2019-03-25  0.649211   0.008340  0.018164  0.888528
# 2019-03-26  0.409829   0.499562  0.574171  0.893186
# 2019-03-27  0.897526   0.174864  0.520350  0.499903
# 2019-03-28  0.282238   0.122382  0.923633  0.961314
# 2019-03-29  0.268250   0.192541  0.098260  0.325771
# 2019-03-30  0.644421   0.326421  0.051929  0.097123
# 2019-03-31  0.196899   0.582008  0.809187  0.690348
# 2019-04-01  0.859787   0.436628  0.415016  0.256779
# 2019-04-02  0.104428   0.023266  0.192291  0.194863
# 2019-04-03  0.458663   0.577656  0.764415  0.450646
# 2019-04-04  0.122169   0.774186  0.254226  0.353068
# 2019-04-05  0.347653   0.389616  0.492403  0.047347
# 2019-04-06  0.049156   0.926383  0.962033  0.566607
# 2019-04-07  0.781070   0.545141  0.570053  0.714138
# ...

# %%
group=a.groupby(level=0)

# %%
group.mean()
# Out:
#              chennai  hyderabad  banglore     delhi
# 2019-01-02  0.468631   0.062762  0.689010  0.944592
# 2019-01-03  0.851682   0.768916  0.018797  0.502806
# 2019-01-04  0.473615   0.349498  0.926514  0.550030
# 2019-01-05  0.754669   0.926630  0.678578  0.953003
# 2019-01-06  0.273504   0.115278  0.818043  0.109099
# 2019-01-07  0.939871   0.478609  0.233282  0.859676
# 2019-01-08  0.300529   0.083427  0.578055  0.539532
# 2019-01-09  0.075539   0.324664  0.566715  0.979672
# 2019-01-10  0.771520   0.128371  0.715771  0.801009
# 2019-01-11  0.104222   0.866722  0.154804  0.393961
# 2019-01-12  0.000356   0.931180  0.212023  0.760485
# 2019-01-13  0.192820   0.629069  0.337680  0.859940
# 2019-01-14  0.869013   0.138310  0.692786  0.501306
# 2019-01-15  0.194098   0.025108  0.819780  0.346780
# 2019-01-16  0.286790   0.285836  0.836110  0.965151
# 2019-01-17  0.835629   0.473382  0.828807  0.492978
# 2019-01-18  0.541079   0.375025  0.553995  0.785354
# ...

# %%
a.groupby(by="chennai")

# %%
b=a["chennai"].unique()

# %%
b=a.count()

# %%
b
# Out:
# chennai      100
# hyderabad    100
# banglore     100
# delhi        100
# dtype: int64

# %%
pd.date_range(start="1/1/2020",periods=5,freq=pd.offsets.MonthBegin(3))
# Out:
# DatetimeIndex(['2020-01-01', '2020-04-01', '2020-07-01', '2020-10-01',
#                '2021-01-01'],
#               dtype='datetime64[ns]', freq='3MS')

# %%
pd.date_range(start="1/1/2020",periods=5,freq="MS")
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01'],
#               dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# ## Time

# %%
from pandas.tseries.offsets import Hour,Minute

# %%
h=Hour(4)

# %%
h
# Out:
# <4 * Hours>

# %%
m=Minute(30)
m
# Out:
# <30 * Minutes>

# %%
pd.date_range("2/2/2020","3/4/2020 23:59",freq="4H")
# Out:
# DatetimeIndex(['2020-02-02 00:00:00', '2020-02-02 04:00:00',
#                '2020-02-02 08:00:00', '2020-02-02 12:00:00',
#                '2020-02-02 16:00:00', '2020-02-02 20:00:00',
#                '2020-02-03 00:00:00', '2020-02-03 04:00:00',
#                '2020-02-03 08:00:00', '2020-02-03 12:00:00',
#                ...
#                '2020-03-03 08:00:00', '2020-03-03 12:00:00',
#                '2020-03-03 16:00:00', '2020-03-03 20:00:00',
#                '2020-03-04 00:00:00', '2020-03-04 04:00:00',
#                '2020-03-04 08:00:00', '2020-03-04 12:00:00',
#                '2020-03-04 16:00:00', '2020-03-04 20:00:00'],
#               dtype='datetime64[ns]', length=192, freq='4H')

# %%
pd.date_range("2/2/2020","3/4/2020 23:59",freq="1H30MIN")
# Out:
# DatetimeIndex(['2020-02-02 00:00:00', '2020-02-02 01:30:00',
#                '2020-02-02 03:00:00', '2020-02-02 04:30:00',
#                '2020-02-02 06:00:00', '2020-02-02 07:30:00',
#                '2020-02-02 09:00:00', '2020-02-02 10:30:00',
#                '2020-02-02 12:00:00', '2020-02-02 13:30:00',
#                ...
#                '2020-03-04 09:00:00', '2020-03-04 10:30:00',
#                '2020-03-04 12:00:00', '2020-03-04 13:30:00',
#                '2020-03-04 15:00:00', '2020-03-04 16:30:00',
#                '2020-03-04 18:00:00', '2020-03-04 19:30:00',
#                '2020-03-04 21:00:00', '2020-03-04 22:30:00'],
#               dtype='datetime64[ns]', length=512, freq='90T')

# %%
s=pd.date_range("3/1/2020",periods=10)
s
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
for i in s:
    print(i.dayofweek,i.weekday_name)
# Out:
# 6 Sunday
# 0 Monday
# 1 Tuesday
# 2 Wednesday
# 3 Thursday
# 4 Friday
# 5 Saturday
# 6 Sunday
# 0 Monday
# 1 Tuesday
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead

# %%
a=pd.Series(np.random.rand(10),index=pd.date_range(start="18/2/1999",periods=10))

# %%
a
# Out:
# 1999-02-18    0.992373
# 1999-02-19    0.200367
# 1999-02-20    0.740928
# 1999-02-21    0.363557
# 1999-02-22    0.899107
# 1999-02-23    0.891942
# 1999-02-24    0.663661
# 1999-02-25    0.602557
# 1999-02-26    0.587609
# 1999-02-27    0.552688
# Freq: D, dtype: float64

# %%
a.shift(2)
# Out:
# 1999-02-18         NaN
# 1999-02-19         NaN
# 1999-02-20    0.992373
# 1999-02-21    0.200367
# 1999-02-22    0.740928
# 1999-02-23    0.363557
# 1999-02-24    0.899107
# 1999-02-25    0.891942
# 1999-02-26    0.663661
# 1999-02-27    0.602557
# Freq: D, dtype: float64

# %%
a.shift(-2)
# Out:
# 1999-02-18    0.740928
# 1999-02-19    0.363557
# 1999-02-20    0.899107
# 1999-02-21    0.891942
# 1999-02-22    0.663661
# 1999-02-23    0.602557
# 1999-02-24    0.587609
# 1999-02-25    0.552688
# 1999-02-26         NaN
# 1999-02-27         NaN
# Freq: D, dtype: float64

# %%
a.shift(2,freq="D")
# Out:
# 1999-02-20    0.992373
# 1999-02-21    0.200367
# 1999-02-22    0.740928
# 1999-02-23    0.363557
# 1999-02-24    0.899107
# 1999-02-25    0.891942
# 1999-02-26    0.663661
# 1999-02-27    0.602557
# 1999-02-28    0.587609
# 1999-03-01    0.552688
# Freq: D, dtype: float64

# %%
a.shift(1,freq="90T")
# Out:
# 1999-02-18 01:30:00    0.992373
# 1999-02-19 01:30:00    0.200367
# 1999-02-20 01:30:00    0.740928
# 1999-02-21 01:30:00    0.363557
# 1999-02-22 01:30:00    0.899107
# 1999-02-23 01:30:00    0.891942
# 1999-02-24 01:30:00    0.663661
# 1999-02-25 01:30:00    0.602557
# 1999-02-26 01:30:00    0.587609
# 1999-02-27 01:30:00    0.552688
# Freq: D, dtype: float64

# %%
from pandas.tseries.offsets import Day,MonthEnd

# %%
now=datetime.now()

# %%
now
# Out:
# datetime.datetime(2020, 1, 3, 14, 13, 10, 79781)

# %%
now+2*Day()
# Out:
# Timestamp('2020-01-05 14:13:10.079781')

# %%
now+Day()
# Out:
# Timestamp('2020-01-04 14:13:10.079781')

# %%
now+MonthEnd()
# Out:
# Timestamp('2020-01-31 14:13:10.079781')

# %%
now+MonthEnd(2)
# Out:
# Timestamp('2020-02-29 14:13:10.079781')

# %%
a=MonthEnd()
a.rollback(now)
# Out:
# Timestamp('2019-12-31 14:13:10.079781')

# %%
a=MonthEnd()
a.rollforward(now)
# Out:
# Timestamp('2020-01-31 14:13:10.079781')

# %%
import pytz

# %%
pytz.common_timezones[:]
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
t=pytz.timezone('Asia/kolkata')

# %%
t
# Out:
# <DstTzInfo 'Asia/Kolkata' LMT+5:53:00 STD>

# %%
t=pytz.timezone( 'America/Tortola')

# %%
t
# Out:
# <DstTzInfo 'America/Tortola' LMT-1 day, 19:54:00 STD>

# %%
a=pd.date_range(start="1/1/2020",periods=5,freq="MS",tz='Asia/kolkata')

# %%
a
# Out:
# DatetimeIndex(['2020-01-01 00:00:00+05:30', '2020-02-01 00:00:00+05:30',
#                '2020-03-01 00:00:00+05:30', '2020-04-01 00:00:00+05:30',
#                '2020-05-01 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', freq='MS')

# %%
t=pd.Timestamp("2020-03-01 4:00",tz="Asia/kolkata")

# %%
t
# Out:
# Timestamp('2020-03-01 04:00:00+0530', tz='Asia/Kolkata')

# %%
t.tz_convert('Asia/kuwait')
# Out:
# Timestamp('2020-03-01 01:30:00+0300', tz='Asia/Kuwait')

# %%
t
# Out:
# Timestamp('2020-03-01 04:00:00+0530', tz='Asia/Kolkata')
