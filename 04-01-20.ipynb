# %%
import seaborn as sb
import pandas as pd
import numpy as np

# %% [markdown]
# ##  1.show the count of different types of spieces

# %%
a=pd.read_csv('iris.csv')

# %%
a.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
b=a['species'].unique()

# %%
b
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
b.size
# Out:
# 3

# %% [markdown]
# ## 2.find the max ans mean in values of speallength and petallength sepalwidth petalwidth draw a graph

# %%
a.pop('species')
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
# 5         setosa
# 6         setosa
# 7         setosa
# 8         setosa
# 9         setosa
# 10        setosa
# 11        setosa
# 12        setosa
# 13        setosa
# 14        setosa
# 15        setosa
# 16        setosa
# 17        setosa
# 18        setosa
# 19        setosa
# 20        setosa
# 21        setosa
# 22        setosa
# 23        setosa
# 24        setosa
# 25        setosa
# 26        setosa
# 27        setosa
# 28        setosa
# 29        setosa
#          ...
# 120    virginica
# 121    virginica
# 122    virginica
# 123    virginica
# 124    virginica
# 125    virginica
# 126    virginica
# 127    virginica
# 128    virginica
# 129    virginica
# 130    virginica
# 131    virginica
# 132    virginica
# 133    virginica
# 134    virginica
# 135    virginica
# 136    virginica
# 137    virginica
# 138    virginica
# 139    virginica
# 140    virginica
# ...

# %%
import matplotlib.pyplot as plt
x=a.max()
y=a.mean()
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## 3.scatterplot(for sepalllength and pettallength

# %%
import matplotlib.pyplot as plt

sb.scatterplot(a['sepal_length'],a['petal_length'])

# %% [markdown]
# ## 4.bargragh

# %%
plt.bar(a['sepal_length'],a['petal_length'])
# Out:
# <BarContainer object of 150 artists>

# %% [markdown]
# ## 5.jointplot(sepallegth sepalwidth)

# %%
sb.jointplot(a['sepal_length'],a['sepal_width'])

# %% [markdown]
# ## 6.facetgrid(for sepallength and sepalwidth for all spieces)

# %% [markdown]
# ## 7.boxplot(for species and sepalwidth)

# %%
a=pd.read_csv('iris.csv')

# %%
a.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sb.boxplot(a['species'],a['sepal_width'],data=a)

# %% [markdown]
# ## 8.boxplot and striplot(all species and sepallength)

# %%
sb.boxplot(a['species'],a['sepal_length'])

# %%
sb.stripplot(a['species'],a['sepal_length'])

# %% [markdown]
# ## 9.violinplot(for petallength and all spieces)

# %%
sb.violinplot(a['petal_length'],a['species'])

# %% [markdown]
# ## 10.pairplot(for 4 columns with species)

# %%
sb.pairplot(a,hue='species')
