# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1,2,2)
data=np.array([1,2,3,4,5,6,7,8])
plt.plot(data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="785.454528430277">

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(left,'-o')
plt.subplot(1,2,2)
plt.plot(right,'-o')
# Out:
# <img src="data:image/png;base64,..." width="785.454528430277">

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(left,'-o')
plt.subplot(2,2,2)
plt.plot(right,'-o')
plt.subplot(2,2,3)
plt.plot(right,'-o')
plt.subplot(2,2,4)
plt.plot(right,'-o')
# Out:
# <img src="data:image/png;base64,..." width="785.454528430277">

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-o')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot([1,2,3],np.array([50,30,40]),'-x')
# Out:
# <img src="data:image/png;base64,..." width="768.181801531926">

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-o',label='mid1')
plt.legend()
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot([1,2,3],np.array([50,30,40]),'-x',label='mid2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="768.181801531926">

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True,sharey=True)
ax5.plot(data,'-')
# Out:
# <img src="data:image/png;base64,..." width="768.181801531926">

# %%
plt.figure()
data1=np.array([10,30,50,60])
xvls=range(len(data1))
plt.bar(xvls,data1,width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <BarContainer object of 4 artists>

# %%
plt.figure()
data2=np.array([5,10,15,20,25])
xvals=range(len(data2))    #[0,1,2,3,4]
plt.barh(xvals,data2,height=0.3)     #barh,height
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <BarContainer object of 5 artists>

# %%
marks=[50,60,70,50,50,30,50,70,50]
plt.figure()
plt.hist(marks)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (array([1., 0., 0., 0., 0., 5., 0., 1., 0., 2.]),
#  array([30., 34., 38., 42., 46., 50., 54., 58., 62., 66., 70.]),
#  <a list of 10 Patch objects>)

# %%
hight_men_at_20=[4,5,6,4,5,3,2]
plt.figure()
plt.boxplot(hight_men_at_20,whis='range')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# {'whiskers': [<matplotlib.lines.Line2D at 0x275d6c56908>,
#   <matplotlib.lines.Line2D at 0x275d6c70128>],
#  'caps': [<matplotlib.lines.Line2D at 0x275d6c70470>,
#   <matplotlib.lines.Line2D at 0x275d6c707b8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x275d6c65c88>],
#  'medians': [<matplotlib.lines.Line2D at 0x275d6c70b00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x275d6c70e48>],
#  'means': []}

# %% [markdown]
# ## Animation

# %%
import matplotlib.animation as animation
n=100
x=np.random.randn(n)

# %%
def update(curr):
    if curr==n:
        a.event_source.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sampling the normal Distributiion')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a=animation.FuncAnimation(fig,update,interval=100)
# Out:
# <img src="data:image/png;base64,..." width="612.1739257350989">

# %%
plt.figure()
data=np.random.rand(10)
plt.plot(data)
def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {},{} \nand data {},{}'.format(event.x,event.y,event.xdata,event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event',onclick)
# Out:
# <img src="data:image/png;base64,..." width="734.7826239292025">
# 6
